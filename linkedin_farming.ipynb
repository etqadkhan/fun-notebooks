# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd

MANDATORY_METRICS = {
    "Impressions": "impressions",
    "Members reached": "members_reached",
    "Profile viewers from this post": "profile_viewers",
    "Followers gained from this post": "followers_gained",
    "Reactions": "reactions",
    "Comments": "comments",
    "Reposts": "reposts",
    "Saves": "saves",
    "Sends on LinkedIn": "sends",
}

IST_TZ = "Asia/Kolkata"

def clean_numeric(value):
    if pd.isna(value):
        return None
    if isinstance(value, str):
        value = value.replace(",", "").strip()
    return pd.to_numeric(value, errors="coerce")

def load_linkedin_post_analytics(directory_path: str) -> pd.DataFrame:
    posts = []

    for file in os.listdir(directory_path):
        if not file.lower().endswith(".xlsx"):
            continue

        file_path = os.path.join(directory_path, file)
        df_raw = pd.read_excel(file_path, header=0)

        post_url = df_raw.columns[1]
        df_raw.columns = ["metric", "value"]
        df_raw = df_raw.dropna(subset=["metric"])

        metric_map = dict(zip(df_raw["metric"], df_raw["value"]))

        post_date = metric_map.get("Post Date")
        post_time = metric_map.get("Post Publish Time")

        # UTC → IST datetime
        post_datetime_utc = pd.to_datetime(
            f"{post_date} {post_time}",
            errors="coerce",
            utc=True
        )
        post_datetime_ist = post_datetime_utc.tz_convert(IST_TZ)

        post_data = {
            "post_url": post_url,
            "post_date": post_datetime_ist.date() if pd.notna(post_datetime_ist) else None,
            "post_time": post_datetime_ist.time() if pd.notna(post_datetime_ist) else None,
            "post_datetime": post_datetime_ist,
        }

        for raw_key, clean_key in MANDATORY_METRICS.items():
            post_data[clean_key] = clean_numeric(metric_map.get(raw_key))

        posts.append(post_data)

    return pd.DataFrame(posts)

# %%
df = load_linkedin_post_analytics(r'''/Users/etqadkhan/Downloads/linkedin_post_impressions''')

# %%
df = df.sort_values(["post_datetime"]).reset_index(drop=True)

# %%
df
# Out:
#                                              post_url   post_date post_time  \
# 0   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-02  18:02:00
# 1   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-03  12:16:00
# 2   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-04  12:58:00
# 3   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-05  18:00:00
# 4   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-06  18:00:00
# 5   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-07  11:01:00
# 6   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-08  09:12:00
# 7   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-09  16:00:00
# 8   https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-10  15:36:00
# 9   https://www.linkedin.com/feed/update/urn:li:sh...  2026-01-11  11:58:00
# 10  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-12  13:00:00
# 11  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-13  10:37:00
# 12  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-14  10:21:00
# 13  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-15  12:29:00
# 14  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-16  18:00:00
# 15  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-17  17:45:00
# 16  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-18  17:30:00
# 17  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-19  11:00:00
# 18  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-20  15:00:00
# 19  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-21  11:00:00
# 20  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-22  18:00:00
# 21  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-23  09:30:00
# 22  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-24  12:23:00
# 23  https://www.linkedin.com/feed/update/urn:li:ug...  2026-01-25  20:09:00
#
#                post_datetime  impressions  members_reached  profile_viewers  \
# 0  2026-01-02 18:02:00+05:30         1047              628                8
# 1  2026-01-03 12:16:00+05:30          863              562                7
# 2  2026-01-04 12:58:00+05:30         1003              657                5
# 3  2026-01-05 18:00:00+05:30          881              572                7
# 4  2026-01-06 18:00:00+05:30          681              457                3
# 5  2026-01-07 11:01:00+05:30          918              629                6
# 6  2026-01-08 09:12:00+05:30          517              336                6
# 7  2026-01-09 16:00:00+05:30          412              274                3
# 8  2026-01-10 15:36:00+05:30          597              388                1
# 9  2026-01-11 11:58:00+05:30          504              301                5
# 10 2026-01-12 13:00:00+05:30          454              299                2
# 11 2026-01-13 10:37:00+05:30          686              448                2
# 12 2026-01-14 10:21:00+05:30          433              270                5
# 13 2026-01-15 12:29:00+05:30          376              237                2
# 14 2026-01-16 18:00:00+05:30          345              223                2
# 15 2026-01-17 17:45:00+05:30          675              461                3
# 16 2026-01-18 17:30:00+05:30          675              462                8
# 17 2026-01-19 11:00:00+05:30          487              335                2
# 18 2026-01-20 15:00:00+05:30          366              250                2
# 19 2026-01-21 11:00:00+05:30          272              162                2
# 20 2026-01-22 18:00:00+05:30          259              186                1
# 21 2026-01-23 09:30:00+05:30          294              197                1
# 22 2026-01-24 12:23:00+05:30          407              268                0
# 23 2026-01-25 20:09:00+05:30          304              217                1
#
#     followers_gained  reactions  comments  reposts  saves  sends
# 0                  0         21         0        0      2      0
# 1                  2          9         2        0      3      0
# 2                  2         11         3        0      4      0
# 3                  0         24         0        0      3      0
# 4                  1          6         1        0      1      0
# 5                  0         12         0        0      5      0
# 6                  2         11         2        0      1      0
# 7                  0          4         0        0      0      0
# 8                  0         12         0        0      2      0
# 9                  0         15         1        0      0      0
# 10                 0          6         0        0      0      0
# 11                 2         12         0        2      2      1
# 12                 1          9         2        0      1      0
# 13                 0          4         0        0      0      0
# 14                 0          4         1        0      0      0
# 15                 2          7         0        0      1      0
# 16                 0          3         0        0      1      0
# 17                 0          8         0        0      0      0
# 18                 2          4         0        0      1      0
# 19                 0          2         0        0      0      0
# 20                 0          6         0        0      2      0
# 21                 0          6         0        0      0      1
# 22                 0          7         0        1      2      0
# 23                 0          8         1        0      2      0
